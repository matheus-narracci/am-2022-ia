# %% [markdown]
# ## AM IA

# %%
# %matplotlib inline

# %%
import cv2
import numpy as np
import pytesseract
from matplotlib import pyplot as plt

# Função que mostra a imagem (tons de cinza)
def mostra_imagem(img, title=''):
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.title(title)
    plt.xticks([]), plt.yticks([])
    plt.show()

# Carrega a imagem
img = cv2.imread('Cv.png', cv2.IMREAD_GRAYSCALE)
mostra_imagem(img, 'Original')
#Cria o kernel do filtro da média (5x5)
kernel = np.ones((3,3),np.float32)/25
# Filtra a imagem com o kernel criado, mantendo o mesmo tipo da imagem
img_filt = cv2.filter2D(img,-1,kernel)
mostra_imagem(img_filt, 'Média 5x5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 16>()
#      14 # Carrega a imagem
#      15 img = cv2.imread('Cv.png', cv2.IMREAD_GRAYSCALE)
# ---> 16 mostra_imagem(img, 'Original')
#      17 #Cria o kernel do filtro da média (5x5)
#      18 kernel = np.ones((3,3),np.float32)/25
#
# Input In [2], in mostra_imagem(img, title)
#       7 def mostra_imagem(img, title=''):
#       8     plt.figure()
# ----> 9     plt.imshow(img, cmap='gray')
#      10     plt.title(title)
#      11     plt.xticks([]), plt.yticks([])
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
# ...

# %%
#Testando qual tipo de filtro fica melhor para leitura do tesseract
img = cv2.imread('Cv.png', cv2.IMREAD_GRAYSCALE)
mostra_imagem(img, 'Original')
median = cv2.medianBlur(img, 1)
mostra_imagem(median, 'Filtro da Mediana 1x1')

# %%
img_gau = cv2.imread('Cv.png', cv2.IMREAD_GRAYSCALE)
mostra_imagem(img_gau,'Original')
blur = cv2.GaussianBlur(img_gau, (1,1),0)
mostra_imagem(blur,'Filtro gaussiano')

# %%
#Escolhemos que a sulução que melhor se aplica é a mediana -- adicionamos brilho
brilho = 10
imagem_nova = cv2.add(median, brilho)
mostra_imagem(imagem_nova)

# %%
caminho = r"C:\Users\macha\AppData\Local\Programs\Tesseract-OCR"
pytesseract.pytesseract.tesseract_cmd = caminho + r"\tesseract.exe"
txt = pytesseract.image_to_string(imagem_nova, lang ="por")

print(txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 caminho = r"C:\Users\macha\AppData\Local\Programs\Tesseract-OCR"
# ----> 2 pytesseract.pytesseract.tesseract_cmd = caminho + r"\tesseract.exe"
#       3 txt = pytesseract.image_to_string(imagem_nova, lang ="por")
#       5 print(txt)
#
# NameError: name 'pytesseract' is not defined
